# %% [markdown]
# <a href="https://colab.research.google.com/github/jimmy-io/worksheeets-/blob/master/03_Grouping_Occupation_Exercises_with_solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
users = pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', 
                      sep='|', index_col='user_id')
users.head()
# Out:
#          age gender  occupation zip_code
# user_id
# 1         24      M  technician    85711
# 2         53      F       other    94043
# 3         23      M      writer    32067
# 4         24      M  technician    43537
# 5         33      F       other    15213

# %%
## Discover what is the mean age per occupation

users.groupby('occupation')['age'].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
## Discover the Male ratio per occupation and sort it from the most to the least

users.groupby(['occupation','gender']).count()
# Out:
# ERROR! Session/line number was not unique in
#                       age  zip_code
# occupation    gender
# administrator F        36        36
#               M        43        43
# artist        F        13        13
#               M        15        15
# doctor        M         7         7
# educator      F        26        26
#               M        69        69
# engineer      F         2         2
#               M        65        65
# entertainment F         2         2
#               M        16        16
# executive     F         3         3
#               M        29        29
# healthcare    F        11        11
#               M         5         5
# homemaker     F         6         6
#               M         1         1
# lawyer        F         2         2
#               M        10        10
# librarian     F        29        29
#               M        22        22
# marketing     F        10        10
#               M        16        16
# ...

# %%
## For each occupation, calculate the minimum and maximum ages

users.groupby('occupation')['age'].describe()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 61
#                count       mean        std   min    25%   50%    75%   max
# occupation
# administrator   79.0  38.746835  11.123397  21.0  30.00  37.0  48.00  70.0
# artist          28.0  31.392857   8.668116  19.0  25.00  30.0  39.00  48.0
# doctor           7.0  43.571429  12.501428  28.0  35.50  45.0  48.50  64.0
# educator        95.0  42.010526  10.413264  23.0  33.00  42.0  50.00  63.0
# engineer        67.0  36.388060  11.199236  22.0  28.00  36.0  43.00  70.0
# entertainment   18.0  29.222222  10.056052  15.0  23.00  25.0  33.00  50.0
# executive       32.0  38.718750  10.608075  22.0  31.00  38.5  46.00  69.0
# healthcare      16.0  41.562500  11.313524  22.0  30.50  44.5  49.25  62.0
# homemaker        7.0  32.571429  10.737119  20.0  24.50  32.0  38.50  50.0
# lawyer          12.0  36.750000  10.830303  21.0  28.75  34.0  47.75  53.0
# ...

# %%
##For each combination of occupation and gender, calculate the mean age

users.groupby(['occupation','gender'])['age'].mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
gender_ocup = users.groupby(['occupation', 'gender']).agg({'gender': 'count'})
gender_ocup
# Out:
#                       gender
# occupation    gender
# administrator F           36
#               M           43
# artist        F           13
#               M           15
# doctor        M            7
# educator      F           26
#               M           69
# engineer      F            2
#               M           65
# entertainment F            2
#               M           16
# executive     F            3
#               M           29
# healthcare    F           11
#               M            5
# homemaker     F            6
#               M            1
# lawyer        F            2
#               M           10
# librarian     F           29
#               M           22
# marketing     F           10
#               M           16
# none          F            4
#               M            5
# other         F           36
#               M           69
# programmer    F            6
#               M           60
# retired       F            1
# ...
